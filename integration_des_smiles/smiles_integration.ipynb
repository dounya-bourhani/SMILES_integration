# %%
import os
import time
import torch
from datasets import load_from_disk
from smiles_integration_app import get_drugs_with_edsnlp, get_smiles, create_enriched_reports_dataset

# %% [markdown]
# # Integration des SMILES dans comptes-rendus médicaux

# %% [markdown]
# ## Dictionnaires

# %%
import pandas as pd

chembl = open('../data/chembl_smiles_synonyms.txt','rt') #open the chembl dico
drugbank = open('../data/drugbank_smiles.txt','rt') #open the drugbank dico
dico = open('../data/dico.txt','rt') #open the drugbank dico
df_chembl = pd.read_csv(chembl, sep='\t', names=['id', 'smiles', 'synonyms'])
df_drugbank = pd.read_csv(drugbank, sep='\t', names=['id', 'smiles','synonyms'])
df_dico = pd.read_csv(dico, sep='\t', names=['id', 'smiles','synonyms'])
chembl.close()
drugbank.close()
dico.close()

# %%
print(f"{df_drugbank.shape[0]} médicament dans DrugBank")
print(f"{df_chembl.shape[0]} médicament dans DrugBank")
print(f"{df_dico.shape[0]} médicament dans DrugBank")
# Out:
# 12699 médicament dans DrugBank
# 84877 médicament dans DrugBank
# 96206 médicament dans DrugBank
# 96206 médicament dans DrugBank

# %%
df_drugbank.shape[0] + df_chembl.shape[0]
# Out:
# 97576

# %%
df_dico.head()
# Out:
#    id                       smiles                                 synonyms
# 0   0            BC#N.C=CCCCCN(C)C  ['HEX-5-ENYLDIMETHYLAMINE CYANOBORANE']
# 1   1  BC#N.CCCCCCCCCCCCCCCCCN(C)C  ['HEPTADECYLDIMETHYLAMINE CYANOBORANE']
# 2   2    BC#N.CCCCCCCCCCCCCCCN(C)C  ['DIMETHYLPENTADECYLAMINE CYANOBORANE']
# 3   3      BC#N.CCCCCCCCCCCCCN(C)C    ['DIMETHYLTRIDECYLAMINE CYANOBORANE']
# 4   4       BC#N.CCCCCCCCCCCCN(C)C     ['DODECYLDIMETHYLAMINE CYANOBORANE']

# %% [markdown]
# ## Intégration - test des fonctions

# %%
os.chdir("/home/bourhani@clb.loc/SMILES/scripts")

# Check if the GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# file = "/home/bourhani@clb.loc/SMILES/tests/medical_reports.xlsx" 
# reports = pd.read_excel(file, engine='openpyxl')
file = "/home/bourhani@clb.loc/saepred/data_test/featurized/OncoBERT_nobias_2LAB/train" 
dataset = load_from_disk(file)
dataset
# Out:
# Using device: cuda
# Dataset({
#     features: ['ippr', 'text', 'labels', 'dt_since_first', 'dt_since_last', 'ipp_id', '__index_level_0__', 'input_ids', 'attention_mask'],
#     num_rows: 559820
# })

# %%
# ----------------------------- DRUGS DETECTION -----------------------------
# detect the drugs in the reports and return a dataframe with the drugs in each text
drugs_dataset = dataset.map(get_drugs_with_edsnlp, batched=True, desc="Detect the drugs in the reports")
# Out:
# Detect the drugs in the reports:   0%|          | 0/559820 [00:00<?, ? examples/s]
# Adding terms into the pipeline: 100%|██████████| 1968/1968 [00:00<00:00, 2248.98it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 272.13it/s]
# Adding terms into the pipeline: 100%|██████████| 1968/1968 [00:00<00:00, 2228.45it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 235.95it/s]
# Adding terms into the pipeline: 100%|██████████| 1968/1968 [00:00<00:00, 2196.03it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 226.30it/s]
# Adding terms into the pipeline: 100%|██████████| 1968/1968 [00:00<00:00, 2054.41it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 231.58it/s]
# Adding terms into the pipeline: 100%|██████████| 1968/1968 [00:00<00:00, 2111.29it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 257.40it/s]
# Adding terms into the pipeline: 100%|██████████| 1968/1968 [00:00<00:00, 2156.02it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 237.26it/s]
# Adding terms into the pipeline: 100%|██████████| 1968/1968 [00:00<00:00, 2217.18it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 221.90it/s]
# Adding terms into the pipeline: 100%|██████████| 1968/1968 [00:00<00:00, 2121.44it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 210.73it/s]
# Adding terms into the pipeline:  45%|████▌     | 890/1968 [00:00<00:00, 2203.60it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 # ----------------------------- DRUGS DETECTION -----------------------------
#       2 # detect the drugs in the reports and return a dataframe with the drugs in each text
#       3 dataset_cuda = dataset.with_format("torch", device=device)
# ----> 4 drugs_dataset = dataset_cuda.map(get_drugs_with_edsnlp, batched=True, desc="Detect the drugs in the reports")
#
# File ~/smiles_env/lib/python3.10/site-packages/datasets/arrow_dataset.py:593, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     591     self: "Dataset" = kwargs.pop("self")
#     592 # apply actual function
# --> 593 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     594 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     595 for dataset in datasets:
#     596     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/smiles_env/lib/python3.10/site-packages/datasets/arrow_dataset.py:558, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     551 self_format = {
#     552     "type": self._format_type,
#     553     "format_kwargs": self._format_kwargs,
#     554     "columns": self._format_columns,
#     555     "output_all_columns": self._output_all_columns,
#     556 }
#     557 # apply actual function
# --> 558 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     559 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     560 # re-apply format to the output
#
# File ~/smiles_env/lib/python3.10/site-packages/datasets/arrow_dataset.py:3105, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3099 if transformed_dataset is None:
#    3100     with hf_tqdm(
#    3101         unit=" examples",
#    3102         total=pbar_total,
#    3103         desc=desc or "Map",
#    3104     ) as pbar:
# -> 3105         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3106             if done:
#    3107                 shards_done += 1
#
# File ~/smiles_env/lib/python3.10/site-packages/datasets/arrow_dataset.py:3482, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3478 indices = list(
#    3479     range(*(slice(i, i + batch_size).indices(shard.num_rows)))
#    3480 )  # Something simpler?
#    3481 try:
# -> 3482     batch = apply_function_on_filtered_inputs(
#    3483         batch,
#    3484         indices,
#    3485         check_same_num_examples=len(shard.list_indexes()) > 0,
#    3486         offset=offset,
#    3487     )
#    3488 except NumExamplesMismatchError:
#    3489     raise DatasetTransformationNotAllowedError(
#    3490         "Using `.map` in batched mode on a dataset with attached indexes is allowed only if it doesn't create or remove existing examples. You can first run `.drop_index() to remove your index and then re-add it."
#    3491     ) from None
#
# File ~/smiles_env/lib/python3.10/site-packages/datasets/arrow_dataset.py:3361, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3359 if with_rank:
#    3360     additional_args += (rank,)
# -> 3361 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3362 if isinstance(processed_inputs, LazyDict):
#    3363     processed_inputs = {
#    3364         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3365     }
#
# File ~/SMILES/scripts/smiles_integration_app.py:57, in get_drugs_with_edsnlp(reports)
#      55 nlp.add_pipe("eds.normalizer")
#      56 nlp.add_pipe("eds.sentences")
# ---> 57 nlp.add_pipe("eds.drugs")
#      59 detected_drugs = []
#      60 for text in tqdm(reports['text']):
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/core/pipeline.py:251, in Pipeline.add_pipe(self, factory, first, before, after, name, config)
#     249     if name is None:
#     250         name = factory
# --> 251     pipe = self.create_pipe(factory, name, config)
#     252 else:
#     253     if config is not None:
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/core/pipeline.py:202, in Pipeline.create_pipe(self, factory, name, config)
#     195 try:
#     196     curried_factory: CurriedFactory = Config(
#     197         {
#     198             "@factory": factory,
#     199             **(config if config is not None else {}),
#     200         }
#     201     ).resolve(registry=registry)
# --> 202     pipe = curried_factory.instantiate(nlp=self, path=(name,))
#     203 except ConfitValidationError as e:
#     204     raise e.with_traceback(None)
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/core/registries.py:92, in CurriedFactory.instantiate(obj, nlp, path)
#      90     if name and "name" in parameters:
#      91         kwargs["name"] = name
# ---> 92     obj.instantiated = obj.factory(**kwargs)
#      93 except ConfitValidationError as e:
#      94     obj.error = e
#
# File ~/smiles_env/lib/python3.10/site-packages/confit/registry.py:318, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#     304 @wraps(
#     305     _func,
#     306     assigned=(
#    (...)
#     315 )
#     316 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
#     317     try:
# --> 318         return _resolve_and_validate_call(
#     319             args=args,
#     320             kwargs=kwargs,
#     321             pydantic_func=vd,
#     322             use_self=False,
#     323             invoker=invoker,
#     324             callee=_func,
#     325         )
#     326     except Exception as e:
#     327         if not is_debug() and isinstance(
#     328             e.__cause__, (ValidationError, LegacyValidationError)
#     329         ):
#
# File ~/smiles_env/lib/python3.10/site-packages/confit/registry.py:84, in _resolve_and_validate_call(args, kwargs, pydantic_func, use_self, callee, invoker)
#      81     resolved = values.pop(self_name)
#      83 if invoker is not None:
# ---> 84     invoker(invoked, values)
#      85 else:
#      86     invoked(values)
#
# File ~/smiles_env/lib/python3.10/site-packages/confit/registry.py:423, in Registry.register.<locals>.invoke(func, params)
#     422 def invoke(func, params):
# --> 423     resolved = invoker(func, params) if invoker is not None else func(params)
#     424     if save_params is not None:
#     425         params_to_save = {**save_params, **params}
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/core/registries.py:305, in FactoryRegistry.register.<locals>.register.<locals>.invoke(validated_fn, kwargs)
#     296 if default_config is not None:
#     297     kwargs = (
#     298         Config(default_config)
#     299         .resolve(registry=self.registry)
#     300         .merge(kwargs)
#     301     )
#     302 instantiated = (
#     303     invoker(validated_fn, kwargs)
#     304     if invoker is not None
# --> 305     else validated_fn(kwargs)
#     306 )
#     307 PIPE_META[instantiated] = meta
#     308 return instantiated
#
# File ~/smiles_env/lib/python3.10/site-packages/confit/registry.py:67, in _resolve_and_validate_call.<locals>.invoked(kw)
#      65 except TypeError as type_error:
#      66     raise convert_type_error(type_error, pydantic_func, callee)
# ---> 67 returned = pydantic_func.execute(model_instance)
#      68 if not use_self:
#      69     resolved = returned
#
# File ~/smiles_env/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:222, in ValidatedFunction.execute(self, m)
#     220     return self.raw_function(*args_, **kwargs, **var_kwargs)
#     221 else:
# --> 222     return self.raw_function(**d, **var_kwargs)
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/pipes/ner/drugs/factory.py:110, in create_component(nlp, name, attr, ignore_excluded, ignore_space_tokens, term_matcher, term_matcher_config, label, span_setter)
#      22 @registry.factory.register(
#      23     "eds.drugs",
#      24     assigns=["doc.ents", "doc.spans"],
#    (...)
#      36     span_setter: SpanSetterArg = {"ents": True, "drug": True},
#      37 ):
#      38     """
#      39     The `eds.drugs` pipeline component detects mentions of French drugs (brand names and
#      40     active ingredients) and adds them to `doc.ents`. Each drug is mapped to an
#    (...)
#     108     Science team.
#     109     """
# --> 110     return TerminologyMatcher(
#     111         nlp=nlp,
#     112         name=name,
#     113         regex=dict(),
#     114         terms=get_patterns(),
#     115         attr=attr,
#     116         ignore_excluded=ignore_excluded,
#     117         ignore_space_tokens=ignore_space_tokens,
#     118         term_matcher=term_matcher,
#     119         term_matcher_config=term_matcher_config,
#     120         label=label,
#     121         span_setter=span_setter,
#     122     )
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/pipes/core/terminology/terminology.py:163, in TerminologyMatcher.__init__(self, nlp, name, terms, regex, attr, ignore_excluded, ignore_space_tokens, term_matcher, term_matcher_config, label, span_setter)
#     152     raise ValueError(
#     153         f"Algorithm {repr(term_matcher)} does not belong to"
#     154         f" known matchers [exact, simstring]."
#     155     )
#     157 self.regex_matcher = RegexMatcher(
#     158     attr=attr,
#     159     ignore_excluded=ignore_excluded,
#     160     ignore_space_tokens=ignore_space_tokens,
#     161 )
# --> 163 self.phrase_matcher.build_patterns(nlp=nlp, terms=terms, progress=True)
#     164 self.regex_matcher.build_patterns(regex=regex)
#     166 self.set_extensions()
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/matchers/phrase.pyx:100, in edsnlp.matchers.phrase.EDSPhraseMatcher.build_patterns()
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/matchers/phrase.pyx:112, in edsnlp.matchers.phrase.EDSPhraseMatcher.build_patterns()
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/utils/collections.py:336, in flatten_once(items)
#     335 def flatten_once(items):
# --> 336     for item in items:
#     337         if isinstance(item, list):
#     338             yield from item
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/processing/simple.py:91, in execute_simple_backend.<locals>.process()
#      89 for batch in batches:
#      90     with no_grad(), lc.cache():
# ---> 91         batch = apply_basic_pipes(batch, batch_components)
#      93     if writer is not None:
#      94         result, count = writer.write_worker(batch)
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/processing/simple.py:31, in apply_basic_pipes(docs, pipes)
#      29             docs = pipe.batch_process(docs)
#      30         else:
# ---> 31             docs = [pipe(doc, **kwargs) for doc in docs]
#      32 return docs
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/processing/simple.py:31, in <listcomp>(.0)
#      29             docs = pipe.batch_process(docs)
#      30         else:
# ---> 31             docs = [pipe(doc, **kwargs) for doc in docs]
#      32 return docs
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/core/pipeline.py:322, in Pipeline._ensure_doc(self, text)
#     309 def _ensure_doc(self, text: Union[str, Doc]) -> Doc:
#     310     """
#     311     Ensure that the input is a Doc.
#     312
#    (...)
#     320     Doc
#     321     """
# --> 322     return text if isinstance(text, Doc) else self.make_doc(text)
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/core/pipeline.py:307, in Pipeline.make_doc(self, text)
#     294 def make_doc(self, text: str) -> Doc:
#     295     """
#     296     Create a Doc from text.
#     297
#    (...)
#     305     Doc
#     306     """
# --> 307     return self.tokenizer(text)
#
# File ~/smiles_env/lib/python3.10/site-packages/edsnlp/language.py:116, in EDSTokenizer.__call__(self, text)
#     114     words.append(match.group(1))
#     115     whitespaces.append(bool(match.group(2)))
# --> 116 return Doc(self.vocab, words=words, spaces=whitespaces)
#
# File ~/smiles_env/lib/python3.10/site-packages/spacy/tokens/doc.pyx:291, in spacy.tokens.doc.Doc.__init__()
#
# File ~/smiles_env/lib/python3.10/site-packages/spacy/vocab.pyx:165, in spacy.vocab.Vocab.get()
#
# File ~/smiles_env/lib/python3.10/site-packages/spacy/vocab.pyx:202, in spacy.vocab.Vocab._new_lexeme()
#
# File ~/smiles_env/lib/python3.10/site-packages/spacy/lang/lex_attrs.py:144, in lower(string)
#     140             shape.append(shape_char)
#     141     return "".join(shape)
# --> 144 def lower(string: str) -> str:
#     145     return string.lower()
#     148 def prefix(string: str) -> str:
#
# KeyboardInterrupt:

# %%
# ----------------------------- SMILES TRANSFORMATION -----------------------------
# find their corresponding smiles and return a dataframe with smiles for each drugs
drugs_dataset_cuda = drugs_dataset.with_format("torch", device=device)
smiles_dataset = drugs_dataset.map(get_smiles, batched=True, desc="Get the smiles formula for each drugs")

# %%
smiles_dataset = load_from_disk("/home/bourhani@clb.loc/saepred/data_test/featurized/smiles_dataset/train")
smiles_dataset
# Out:
# Dataset({
#     features: ['ippr', 'text', 'labels', 'dt_since_first', 'dt_since_last', 'ipp_id', '__index_level_0__', 'input_ids', 'attention_mask', 'drugs', 'smiles'],
#     num_rows: 559820
# })

# %%
save_path = "/home/bourhani@clb.loc/saepred/data_test/featurized/OncoBERT_nobias_2LAB_smiles/train"
enriched_dataset = create_enriched_reports_dataset(smiles_dataset, save_path)
# Out:
# Replacing drug name by their smiles:   0%|          | 0/559820 [00:00<?, ? examples/s]
# Saving the dataset (0/6 shards):   0%|          | 0/559820 [00:00<?, ? examples/s]

# %% [markdown]
# ### Verifications

# %%
train = load_from_disk("/home/bourhani@clb.loc/saepred/data_test/featurized/OncoBERT_nobias_2LAB_smiles/train")

# %%
max_drugs_entry = max(train["drugs"], key=len)
max_drugs_index = train["drugs"].index(max_drugs_entry)

# %%
print(train[max_drugs_index]['drugs'])
print("")
print(train[max_drugs_index]['smiles'])
print("")
print(train[max_drugs_index]['text'])
print("")
print(train[max_drugs_index]['enriched_text'])
# Out:
# ['ACICLOVIR', 'ACICLOVIR', 'ALBUMINE', 'ALBUMINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARACYTINE', 'ARTISIAL', 'ARTISIAL', 'ARTISIAL', 'ARTISIAL', 'ARTISIAL', 'AXEPIM', 'AXEPIM', 'AXEPIM', 'BETADINE', 'CANDESARTAN', 'CANDESARTAN', 'CANDESARTAN', 'CANDESARTAN', 'CANDESARTAN', 'CANDESARTAN', 'CANDESARTAN', 'CANDESARTAN', 'CEFEPIME', 'CEFEPIME', 'CEFEPIME', 'CEFOTAXIME', 'CEFOTAXIME', 'CIFLOX', 'CIFLOX', 'CIFLOX', 'CIPROFLOXACINE', 'CIPROFLOXACINE', 'CIPROFLOXACINE', 'CIPROFLOXACINE', 'CIPROFLOXACINE', 'COBALT', 'COBALT', 'EUPANTOL', 'EUPANTOL', 'FASTURTEC', 'FASTURTEC', 'FENTANYL', 'FLAGYL', 'FLAGYL', 'FLAGYL', 'FLAGYL', 'FLAGYL', 'FLUCONAZOLE', 'FLUCONAZOLE', 'FLUCONAZOLE', 'FLUCONAZOLE', 'FLUCONAZOLE', 'FORLAX', 'FORLAX', 'FUNGIZONE', 'GLUCOSE', 'GLUCOSE', 'HYDROCORTISONE', 'HYDROCORTISONE', 'HYDROCORTISONE', 'HYDROCORTISONE', 'HYDROCORTISONE', 'HYDROCORTISONE', 'KAYEXALATE', 'KAYEXALATE', 'KESTIN', 'KESTIN', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHOTREXATE', 'METHYLPREDNISOLONE', 'MORPHINE', 'MORPHINE', 'NEFOPAM', 'NEFOPAM', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'NILOTINIB', 'ONDANSETRON', 'OSMOGEL', 'OXYCODONE', 'OXYNORM', 'OXYNORM', 'OXYNORM', 'OXYNORM', 'OXYNORM', 'OXYNORM', 'PARACETAMOL', 'PENTACARINAT', 'PENTACARINAT', 'POLARAMINE', 'POTASSIUM', 'POTASSIUM', 'PRIMPERAN', 'PRIMPERAN', 'SALBUTAMOL', 'SALBUTAMOL', 'SALBUTAMOL', 'SPASFON', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TAZOCILLINE', 'TOPALGIC', 'TOPALGIC', 'TRAMADOL', 'TRAMADOL', 'TRAMADOL', 'TRAMADOL', 'TRAMADOL', 'TRAMADOL', 'TRAMADOL', 'TRAMADOL', 'VALACICLOVIR', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VINCRISTINE', 'VOLTARENE', 'VOLTARENE', 'VOLTARENE', 'ZELITREX', 'ZELITREX', 'ZYVOXID', 'ZYVOXID', 'ZYVOXID']
#
# ['NC1=NC(=O)C2=C(N1)N(COCCO)C=N2', 'NC1=NC(=O)C2=C(N1)N(COCCO)C=N2', None, None, 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', 'NC1CCN([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)C(=O)N1', '[Cl-].[Cl-].[Ca++]', '[Cl-].[Cl-].[Ca++]', '[Cl-].[Cl-].[Ca++]', '[Cl-].[Cl-].[Ca++]', '[Cl-].[Cl-].[Ca++]', 'CO\\N=C(/C(=O)N[C@@H]1C(=O)N2[C@]1([H])SCC(C[N+]1(C)CCCC1)=C2C([O-])=O)C1=CSC(N)=N1', 'CO\\N=C(/C(=O)N[C@@H]1C(=O)N2[C@]1([H])SCC(C[N+]1(C)CCCC1)=C2C([O-])=O)C1=CSC(N)=N1', 'CO\\N=C(/C(=O)N[C@@H]1C(=O)N2[C@]1([H])SCC(C[N+]1(C)CCCC1)=C2C([O-])=O)C1=CSC(N)=N1', 'CCCCCCCCCCCCOCCOCCOCCOCCOCCOCCOCCOCCOCCO', 'CCOC1=NC2=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NN=NN1)C(=CC=C2)C(=O)OC(C)OC(=O)OC1CCCCC1', 'CCOC1=NC2=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NN=NN1)C(=CC=C2)C(=O)OC(C)OC(=O)OC1CCCCC1', 'CCOC1=NC2=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NN=NN1)C(=CC=C2)C(=O)OC(C)OC(=O)OC1CCCCC1', 'CCOC1=NC2=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NN=NN1)C(=CC=C2)C(=O)OC(C)OC(=O)OC1CCCCC1', 'CCOC1=NC2=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NN=NN1)C(=CC=C2)C(=O)OC(C)OC(=O)OC1CCCCC1', 'CCOC1=NC2=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NN=NN1)C(=CC=C2)C(=O)OC(C)OC(=O)OC1CCCCC1', 'CCOC1=NC2=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NN=NN1)C(=CC=C2)C(=O)OC(C)OC(=O)OC1CCCCC1', 'CCOC1=NC2=C(N1CC1=CC=C(C=C1)C1=CC=CC=C1C1=NN=NN1)C(=CC=C2)C(=O)OC(C)OC(=O)OC1CCCCC1', 'CO/N=C(\\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[N+]3(C)CCCC3)CS[C@H]12)C1CSC(N)N1', 'CO/N=C(\\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[N+]3(C)CCCC3)CS[C@H]12)C1CSC(N)N1', 'CO/N=C(\\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[N+]3(C)CCCC3)CS[C@H]12)C1CSC(N)N1', 'CO/N=C(\\C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(COC(C)=O)CS[C@H]12)C1CSC(N)N1', 'CO/N=C(\\C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(COC(C)=O)CS[C@H]12)C1CSC(N)N1', 'CL.O=C(O)C1CN(C2CC2)C2CC(N3CCNCC3)C(F)CC2C1=O', 'CL.O=C(O)C1CN(C2CC2)C2CC(N3CCNCC3)C(F)CC2C1=O', 'CL.O=C(O)C1CN(C2CC2)C2CC(N3CCNCC3)C(F)CC2C1=O', 'OC(=O)C1=CN(C2CC2)C2=CC(N3CCNCC3)=C(F)C=C2C1=O', 'OC(=O)C1=CN(C2CC2)C2=CC(N3CCNCC3)=C(F)C=C2C1=O', 'OC(=O)C1=CN(C2CC2)C2=CC(N3CCNCC3)=C(F)C=C2C1=O', 'OC(=O)C1=CN(C2CC2)C2=CC(N3CCNCC3)=C(F)C=C2C1=O', 'OC(=O)C1=CN(C2CC2)C2=CC(N3CCNCC3)=C(F)C=C2C1=O', '[Co]', '[Co]', None, None, None, None, 'CCC(=O)N(C1CCCCC1)C1CCN(CCC2CCCCC2)CC1', 'CC1=NC=C(N1CCO)[N+]([O-])=O', 'CC1=NC=C(N1CCO)[N+]([O-])=O', 'CC1=NC=C(N1CCO)[N+]([O-])=O', 'CC1=NC=C(N1CCO)[N+]([O-])=O', 'CC1=NC=C(N1CCO)[N+]([O-])=O', 'OC(CN1C=NC=N1)(CN1C=NC=N1)C1=C(F)C=C(F)C=C1', 'OC(CN1C=NC=N1)(CN1C=NC=N1)C1=C(F)C=C(F)C=C1', 'OC(CN1C=NC=N1)(CN1C=NC=N1)C1=C(F)C=C(F)C=C1', 'OC(CN1C=NC=N1)(CN1C=NC=N1)C1=C(F)C=C(F)C=C1', 'OC(CN1C=NC=N1)(CN1C=NC=N1)C1=C(F)C=C(F)C=C1', None, None, 'C[C@@H]1[C@H](O)[C@@H](C)/C=C/C=C/C=C/C=C/C=C/C=C/C=C/[C@H](O[C@@H]2O[C@H](C)[C@@H](O)[C@H](N)[C@@H]2O)C[C@@H]2O[C@](O)(C[C@@H](O)C[C@@H](O)[C@H](O)CC[C@@H](O)C[C@@H](O)CC(=O)O[C@H]1C)C[C@H](O)[C@H]2C(=O)O', 'CCCC(=O)NC1=C(I)C=C(I)C(CC(CC)C(O)=O)=C1I', 'CCCC(=O)NC1=C(I)C=C(I)C(CC(CC)C(O)=O)=C1I', 'C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2[C@@H](O)C[C@@]2(C)[C@H]1CC[C@]2(O)C(=O)CO', 'C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2[C@@H](O)C[C@@]2(C)[C@H]1CC[C@]2(O)C(=O)CO', 'C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2[C@@H](O)C[C@@]2(C)[C@H]1CC[C@]2(O)C(=O)CO', 'C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2[C@@H](O)C[C@@]2(C)[C@H]1CC[C@]2(O)C(=O)CO', 'C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2[C@@H](O)C[C@@]2(C)[C@H]1CC[ ...
#
# ## compte - rendu de séjour
# ### contenu
# hospitalisation pour bilan tumoral initial , autre motif d ' hospitalisation anémie liée à la maladie tumorale , douleur aiguë , douleurs abdominales
# [date] bilan tumoral ( évolutivité ) : maladie progressive
# examen clinique carcinologique normal
# traitement durant le séjour
# transfusion
# chimiothérapie iv
# chimiothérapie intrathécale
# thérapeutique anti - néoplasique ciblée
# hydratation
# patient faisant parti d ' un essai thérapeutique
# antalgique palier 2
# morphiniques - pca ( morphine , oxynorm , fentanyl , sufentanyl )
# paracétamol
# antibiothérapie curative
# antifongiques locaux
# antifongiques systémiques
# antiviraux
# pose de piccs
# ablation de picc
# isolement protecteur avec chambre à flux
# transfusion de culots globulaires
# transfusion plaquettaire
# soins intensifs hématologiques hors greffe
# nutrition entérale par sonde
# compléments nutritionnels
# pose de sng d ' alimentation
# pose de sonde à demeure
# antidiarrhéiques
# antiémétique
# ipp
# lavement
# laxatifs
# actes médicaux effectués dans le service :
# [date] séance d ' injection intrathécale d ' agent pharmacologique anticancéreux , par voie transcutanée [nom]
# [date] ponction de mo pour myélogramme et analyses bio dans un territoire , par voie transcutanée [nom]
# [date] séance d ' injection intrathécale d ' agent pharmacologique anticancéreux , par voie transcutanée [nom]
# 10/03/2020 séance d ' administ . intraventric . ou intrakyst . cérébrale d ' agent anticanc . , par un dispo . implanté [nom]
# [date] ponction de mo pour myélogramme et analyses bio dans un territoire , par voie transcutanée [nom]
# commentaires
# resume de l ' hositalisation : patiente de 57 ans hospitalisée pour début de prise en charge d ' une lal phi +
# motif d ' admission : patiente de 57 ans hospitalisée pour début de prise en charge d ' une lal phi +
# antecedents :
# 1 ) médicaux
# \- hta , traitée par candesartan
# \- lombalgie
# \- surdité partielle od
# \- coxarthrose
# 2 ) chirurgicaux
# \- chirurgie de l ' humerus droit
# \- appendicectomie
# 3 ) familiaux :
# \- leucémie aigüe chez la mère
# \- cancer du pancréas chez le frère
# \- cardiopathie chez la sœur
# allergies :
# \- pénicillines et voltarene ( notion d ' angio - oedemes )
# \- graminés
# toxiques :
# \- tabac : 5 cigarettes / jour depuis plusieurs années
# \- alcool : 1 verre à chaque repas
# traitement habituel :
# \- candesartan
# \- tramadol
# \- kestin pour sa rhinite
# mode de vie :
# vit avec son mari , sans enfants , parfaitement autonome à domicile et travaille comme saisonnière en agriculture . notion d ' exposition au nickel et au cobalt lors de son précédent travail dans une bijouterie ( eczéma corps entier avec arrêt de travail pendant 1 an ) .
# fratrie : neuf frères et sœurs dont les coordonnées ont été recueillies , un est atteint d ' anévrysme sans précision , et un autre de maladie de parkinson .
# histoire de la maladie :
# la patiente consulte aux urgences du centre hospitalier de valence le [date] pour des douleurs abdominales prédominant en fosse iliaque gauche , apparues une semaine avant , associé à une asthénie intense et perte de 6 kg en 1 mois sans régime . elle est stable sur le plan hémodynamique , apyrétique . la bio met en évidence une hyperleucocytose à 350 g/l avec une blastose importante faisant poser le diagnostic de leucémie aigüe , un acide urique à 380 mmol/l et une kaliémie à 6 . 9 mmol/l sans signe électriques à l ' ecg . elle reçoit un traitement par salbutamol , kayexalate , insuline glucose et hyperhydratation et est transférée en réanimation au pavillon h de heh .
# durant son séjour à heh : contrôle de l ' hyperuricémie avec une dose de fasturtec . sur le plan pulmonaire , un scan thoracique retrouve des condensation bi - basales d ' allures infectieuses avec une lame d ' épanchement pleural bilatéral motivant un début d ' atb par cefotaxime et recherche de grippe qui s ' avère négative . devant ces douleurs abdominales intenses , un tdm - tap est réalisé retrouvant une splénomégalie homogène , pas de complication abdominale notamment pancréatique et digestive , ni d ' adp profonde . episode de surcharge hydrosodée post hyperhydratation sur prévention d ' un syndrome de lyse . a la fin du séjour : k+ à 4 . 8 , hb : 81 , plt : 43 , créat ' à 64 , bilan de coag ' normal ( tp : 73 % tca à 0 . 99 et fibrinogène à 5 . 24 ) . immunophénotypage en raison d ' une lal avec phi+
# transfert du 2bs le 06/03 pour la suite de la prise en charge .
# examen du patient a l ' admission
# poids : 63 kg taille : 156 cm ps 2 apyrétique
# sur le plan cardiaque : bdc réguliers , sans bruits surajoutés , pas de signe de tvp , rhj , tj , pas d ' omi
# sur le plan pulmonaire : murmure vésiculaire bilatéraux et symétriques , fin crépitant aux bases , pas de dyspnée en aa , toux grasse depuis quelques jours à priori
# sur le plan abdominal : pas d ' organomégalie . palpation sensible ( hypochondre droit + épigastre ++ ) , la patiente se plaint d ' une douleur en barre au niveau épigastrique ( scanner normal fait en réa , mais patiente très angoissée ) . transit ok
# sur le plan thymique : patiente très angoissé demandeuse de traitements . elle ne désire pas voir de psychologue pour l ' instant .
# sur le plan cutanée : ras
# pas de sfu
# aires ganglionnaires libres
# biologie a l ' admission : bilan du 06/03
# nfp : gb : 293 g/l pnn : 8 . 81 g/l ly : 8 . 81 g/l hb : 84 g/l plq : 38 g/l blastes : 94 %
# coagulation : ratio tca 0 . 84 tp 73 % inr 1 . 24 fibronogène 5 . 77g/l
# ionogramme : sodium 138 potassium 3 . 1 chlore 104 bicarbonates 23
# albumine 32g/l
# créatinine/mdrd : 67 µmol/l dfg 87ml/min
# bilan hépatique normal / ldh 828 :
# crp : 185
# ferritine : 1654
# sérologies vih , vha , vhb , vhc , ebv , cmv , hsv :
# anticorps igg anti - vca et igg anti - ebna positifs , tous les autres sont négatifs ( notamment pas de contact avec le vhb , ni vaccination )
# bilan diagnostique ( date )
# myélogramme : non réalisé compte - tenu de la blastose sanguine
# bilan pre - therapeutique
# ecg : rythme sinusal régulier , tracé sans particularité
# ett : non réalisé dans un premier temps
# rp : sans particularité en dehors d ' une distension thoracique avec horizontalisation des côtes , et émoussement du cul de sac pleural bilatéral
# pose de vvc ( type et date ) : pose d ' un picc line le 09/03
# groupage hla : o rh positif ( rh : 1 )
# cecos : non réalisé
# nb : mise en évidence d ' une infiltration méningée de la leucémie le 10/03
# protocole de chimiotherapie ( préciser si patient inclus dans un protocole )
# rcp : le 10/03 , validation de l ' inclusion dans l ' essai national graaph
# date du début : préface de corticoïdes à partir du 08/03 , puis début du protocole le 16/03
# molécules :
# \- ec nilotinib 400 mg ( j1 [date] )
# \- ec nilotinib 400 mg ( j1 [date] )
# \- vincristine 2 mg ( j1 [date] )
# \- ec nilotinib 400 mg ( j2 [date] )
# \- ec nilotinib 400 mg ( j2 [date] )
# \- aracytine 40 mg ( j8 [date] )
# \- hydrocortisone 40 mg ( j8 [date] )
# \- methotrexate intrat 15 mg ( j8 [date] )
# \- ec nilotinib 400 mg ( j8 [date] )
# \- vincristine 2 mg ( j8 [date] )
# \- ec nilotinib 400 mg ( j9 [date] )
# \- ec nilotinib 400 mg ( j1 [date] )
# \- ec nilotinib 400 mg ( j1 [date] )
# \+ pl simple le 10/03 , et triple les 16/03 et 23/03 :
# \- methotrexate intrat 15 mg ( j1 10/03/2020 )
# evolution durant le sejour
# hématologique :
# administration du premier cycle de chimiothérapie à partir du 16/03 :
# \- aracytine 40 mg ( j1 [date] )
# \- hydrocortisone 40 mg ( j1 [date] )
# \- methotrexate intrat 15 mg ( j1 [date] )
# \- vincristine 2 mg ( j1 [date] )
# \- aracytine 40 mg ( j8 [date] )
# \- hydrocortisone 40 mg ( j8 [date] )
# \- methotrexate intrat 15 mg ( j8 [date] )
# \- vincristine 2 mg ( j8 [date] )
# \- vincristine 2 mg ( j15 [date] )
# \- vincristine 2 mg ( j22 [date] )
# ponction lombaire diagnostique ( et injection de methotrexate ) le 10/03 envahie .
# la chimiothérapie intrathécale a été administrée au j1 ( 16/03 ) et au j8 ( 23/03 ) uniquement : des céphalées apparues au décours du j8 on fait réaliser un scanner cérébral ( 27/03 ) qui retrouvait un hématome sous - dural bilatéral . le scanner a été contrôlé une semaine plus tard , et trois semaines plus tard : persistance de l ' hsd bilatéral avec signes de saignement récent . on contre - indique donc les ponctions lombaires , et on maintien un taux de plaquettes > 50g/l . les céphalées se sont peu à peu amendées grâce au tramadol et à la corticothérapie ( un avis neurochirurgical avait été pris auprès de [doctor] du médipôle )
# bilan médullaire le 14/04 , avant d ' initier le deuxième cycle :
# \- cytologie : prélèvement médullaire où l ' on observe de rares cellules immatures ( < 1 % ) dont le caractère blastique est à confronter au résultat du bilan complémentaire . aspect de rémission cytologique .
# \- biologie moléculaire : bcr \- abl 6 . 1 % dans la moelle , 3 % dans le sang
# administration du 2ème cycle à partir du 15/04 :
# \- methotrexate 1500 mg ( j1 [date] )
# \- aracytine 2300 mg ( j2 [date] )
# \- aracytine 2300 mg ( j2 [date] )
# \- aracytine 2300 mg ( j3 [date] )
# \- aracytine 2300 mg ( j3 [date] )
# ce deuxième cycle a été compliqué d ' une toxicité hépatique ( cytolyse et cholestase anictérique , avec échographie et scanner retrouvant une dilatation des voies biliaires intra - hépatiques , sans signe en faveur d ' une maladie veino occlusive ) et d ' une insuffisance rénale aigue , avec retard à l ' élimination du méthotrexate , de correction rapide après suspension des médicaments néphro - et hépato - toxiques .
# dans ce contexte , le nilotinib a été suspendu du 20/04 au 24/04 .
# on note une normalisation des bilan hépatiques et rénaux le 27/04 .
# o date pnn < 0 , 5g/l : 19/04 pour le deuxième cycle
# o date pnn > 0 , 5g/l : 01/04 pour la premier cycle
# o date plq > 20 g/l : plaquettes maintenues > 50g/l
# sortie d ' aplasie le [date] pour le second cycle , permettant de réaliser un nouveau bilan médullaire le [date] :
# \- cytologie : myélogramme correspondant à une persistance de la rémission cytologique avec une bonne représentation des différentes lignées myéloïdes .
# \- immunophénotypage :
# persistance d ' une mrd2 de la lalb connue ( estimée à 0 , 5 % soit 5x10 - 3 de la cellularité totale ) , avec globalement le même profil antigénique que celui du diagnostic : cd34+cd38+/ - cd19+cd10++cd20 - cd58++ .
# \- biologie moléculaire :
# transcrits bcr - abl1 major en diminution à 0 . 69 % dans la moelle , au lieu de 6 % précédemment .
# o transfusions : type de produits / nb de cgr/ nb de cpa/ nb de mcp/nb de pfc
# infectiologique :
# o antibiotiques ( avec les dates ) :
# administration de pentacarinat préventif le 10/03
# zyvoxid du 08/03 au 21/03 sans documentation pour veinite des deux membres supérieurs
# tazocilline du 14/03 au 16/03 en traitement d ' une angine , puis à partir du 20/03 dans le cadre du protocole graaf
# 07/04 : arrêt de la tazocilline protocolaire
# 18/04 : reprise tazocilline pour aplasie fébrile , et devant la fièvre persistante et la mise en évidence d ' un foyer de crépitants en base gauche , de ciprofloxacine .
# la ciprofloxacine est arrêtée à 48h devant une réaction cutanée , qui peut également être imputable à l ' aracytine , et n ' est pas reprise
# le 20/04 , arrêt de la tazocilline devant la perturbation du bilan hépatique , remplacée par la céfépime .
# le 27/04 , nouvel épisode d ' aplasie fébrile , sous axepim flagyl , d ' évolution favorable .
# mise en évidence d ' un zona thoracique droit le 29/04 , d ' évolution favorable sous aciclovir intraveineux ( dose de charge puis d ' entretien )
# sortie d ' aplasie le 05/05 , permettant un arrêt progressif des antibiotiques , sans récidive fébrile .
# o documentations :
# bactériologiques :
# \- hémocultures négatives jusqu ' au 13/05
# \- ecbu positif à candida puis e coli , sans symptômes donc pas de traitement spécifique .
# \- bmr de type hafnia dans les prélèvements de gorge réalisés à titre systématique .
# mycologiques : aucune au 13/05
# virologiques : aucune au 13/05
# parasitologiques : aucune au 13/05
# o lba ( si réalisé )
# métaboliques :
# o evolution du poids ( +/ - alimentation artificielle ) : dénutrition modérée en raison d ' une perte de poids de plus de 10 % en 6 mois . conseils nutritionnels par la diététicienne du clb .
# au 16/04 , avant le début du deuxième cycle , poids de 53 kg , soit une perte de poids de 10kg . indication théorique de nutrition artificielle , non instaurée dans un premier temps du fait de la mucite et de la perturbation du bilan hépatique . finalement , pose de sonde nasogastrique le [date] , avec augmentation progressive des apports , avec une bonne tolérance jusqu ' à 1500ml/24h à une vitesse de 200ml/heure , sans syndrome de renutrition inapproprié .
# on décide de retirer la sonde nasogastrique le 13/05 , lors de la sortie d ' hospitalisation , la patiente retrouvant un bon appétit . on discutera une nouvelle pose le 25/05 lors de son retour .
# o fonction rénale : épisode d ' insuffisance rénale aigue après l ' administration du deuxième cycle , imputée au methotrexate , résolutif ( autour du 22/04 ) . pas de nouvelle perturbation de la fonction rénale jusqu ' à la sortie .
# o fonction hépatique : toxicité hépatique ( cytolyse et cholestase anictérique , avec échographie et scanner retrouvant une dilatation des voies biliaires intra - hépatiques , sans signe en faveur d ' une maladie veino occlusive ) , autour du 22/04 , résolutif avec le temps et la suspension des médicaments hépatotoxiques . pas de nouvelle perturbation de la fonction hépatique jusqu ' à la sortie .
# o digestive :
# réalisation d ' une échographie abdominale le 11/03 devant des douleurs :
# absence de foyer infectieux profond décelé sur cet examen . hépatomégalie homogène . épanchement pleural bilatéral de faible abondance .
# constipation importante autour du 08/04 associée à des douleurs abdominales , ayant cédé après l ' administration de xprep
# scanner abdomino - pelvien le 08/04 : stase stercorale du cadre colique , marquée au niveau du cæcum .
# nausées ( grade ) : 2
# mucite ( grade ) : le 20/04 , mise en évidence d ' une mucite de grade 3 ayant motivé l ' introduction d ' une pca d ' oxynorm et de fluconazole topique . amélioration progressive des lésions avec la sortie d ' aplasie , permettant un sevrage progressif de la pca .
# diarrhées ( grade ) : absence
# autres : sur le plan neurologique :
# ponction lombaire diagnostique ( et injection de methotrexate ) le 10/03 envahie .
# la chimiothérapie intrathécale a été administrée au j1 ( 16/03 ) et au j8 ( 23/03 ) uniquement : des céphalées apparues au décours du j8 on fait réaliser un scanner cérébral ( 27/03 ) qui retrouvait un hématome sous - dural bilatéral . le scanner a été contrôlé une semaine plus tard , et trois semaines plus tard : persistance de l ' hsd bilatéral avec signes de saignement récent . on contre - indique donc les ponctions lombaires , et on maintien un taux de plaquettes > 50g/l . les céphalées se sont peu à peu amendées grâce au tramadol et à la corticothérapie ( un avis neurochirurgical avait été pris auprès de [doctor] du médipôle )
# pour rappel , on a surveillé à plusieurs reprises le scanner cérébral :
# \- le 27/03 : hématome sous - dural aigu frontopariétal bilatéral prédominant à droite sur hématome sous - dural chronique . lame d ' hématome sous - dural parafalcoriel et de la tente du cervelet .
# \- le 06/04 : lames d ' hématome sous - dural chronique frontopariétales bilatérales prédominant à gauche ( 8 mm d ' épaisseur maximale en frontal gauche ) . aspect plus dense de l ' hématome frontaopariétal droit en faveur d ' un nouveau saignement .
# \- le 20/04 : à l ' étage cérébral , diminution en taille des hématomes sous - duraux des deux convexités . par contre , réapparition d ' une hyperdensité spontanée au sein du décollement sous - dural de la convexité gauche en faveur d ' un resaignement aigu .
# \- le 04/05 : majoration de l ' hématome sous - dural hémisphérique gauche avec signe de resaignement en son sein , responsable d ' un effet de masse sur les structures médianes , déviées vers la droite de 5 mm . majoration également de l ' hématome sous - dural postérieur droit , sans signe de resaignement .
# \- le 11/05 : stabilité de l ' hématome sous - dural chronique hémisphérique gauche avec déviation de la ligne médiane de 3 mm contre 5 mm précédemment . majoration en taille de l ' hématome sous - dural pariéto - occipital droit , partiellement cloisonné de 15 mm d ' épaisseur maximale contre 12 mm précédemment .
# on conclut donc à une persistance de l ' hématome malgré maintien d ' un seuil plaquettaire > 50g/l pendant toute la durée de l ' hospitalisation , nous empêchant de répéter les ponctions lombaires , la dernière ( 23/03 ) étant envahie .
# a noter , deux épisdoes de rectorragies de faible abodance le 13/05 , sans déglobulisation ni anomalie à l ' inspection de la marge anale et du toucher rectal , qui nous font demander une rectosigmoidoscopie pour la prochaine hospitalisation .
# sur le plan hématologique , on décide de prendre un avis auprès du centre expert pour la suite de la conduite à tenir .
# le bon état clinique et psychologique de la patiente permettent un retour à domicile le 14/05 . elle sera convoquée le 25/05 pour la suite du traitement .
# bilan a la sortie
# lieu : domicile
# bilan médullaire : myélogramme répété le 06/05 :
# \- cytologie : myélogramme correspondant à une persistance de la rémission cytologique avec une bonne représentation des différentes lignées myéloïdes .
# \- immunophénotypage :
# persistance d ' une mrd2 de la lalb connue ( estimée à 0 , 5 % soit 5x10 - 3 de la cellularité totale ) , avec globalement le même profil antigénique que celui du diagnostic : cd34+cd38+/ - cd19+cd10++cd20 - cd58++ .
# \- biologie moléculaire :
# transcrits bcr - abl1 major en diminution à 0 . 69 % dans la moelle , au lieu de 6 % précédemment .
# programme thérapeutique : sera reconvoquée le [date] pour la suite du traitement
# traitement de sortie :
# candesartan/ hctz 8 mg/12 . 5 mg ( candesartan/hctz 8 mg/12 , 5mg cpr ) , voie orale , 1 comprime ( s ) 1 fois dans la journée
# ec nilotinib , gelule , voie orale , 400 mg 2/j à 07 : 00 , 19 : 00 pendant 1 mois
# a prendre à distance des repas avec un grand verre d ' eau .
# aucun aliment ne doit être consommé pendant les 2 heures précédant la prise du médicament et pendant 1 heure au moins après celle - ci .
# respecter un intervalle de 12 heure entre les prises .
# artisial ( artisial sol ) , voie buccale , 1 flacon ( s ) pressurise ( s ) 8 - 12 - 18h pendant 1 mois
# pour les nausées :
# \- primperan 10 mg : 1 prise en cas de nausées/vomissements , maximum 3 prises par jour , intervalle minimum
# entre 2 prises de 6 heures
# pour la prévention des infections :
# \- zelitrex 500mg : 1 comprimé matin et soir
# pour la prévention des mucites :
# \- bains de bouche 6 fois par jour avec : bicarbonate 1 . 4 % 250ml ( un flacon par jour )
# pour l ' estomac :
# \- eupantol 20mg : 1 comprimé par jour
# pour les douleurs :
# \- topalgic 50mg : 1 prises en cas de douleurs , maximum 3 prises par jour , intervalle minimum entre 2 prises de 6
# heures
# \- si persistance : ampoule de néfopam 20mg , jusqu ' à trois fois par jour , à boire
# pour la constipation :
# \- forlax sachet : 2 sachets le matin au départ puis 1 sachet matin et soir . si persistance de la constipation , 6 sachets
# par jour maximum .
# liste des transfusions
# cgr unité adulte ( 257 - 297 ml ) [date]mélange de concentrés de plaquettes - mcp 10/03/2020cgr unité adulte ( 257 - 297 ml ) [date]cgr unité adulte ( 257 - 297 ml ) [date]mélange de concentrés de plaquettes - mcp [date]concentre de plaquettes d ' apherese cpa [date]cgr unité adulte ( 257 - 297 ml ) [date]cgr unité adulte ( 257 - 297 ml ) [date]mélange de concentrés de plaquettes - mcp [date]concentre de plaquettes d ' apherese cpa [date]mélange de concentrés de plaquettes - mcp [date]cgr unité adulte ( 257 - 297 ml ) [date]cgr unité adulte ( 257 - 297 ml ) [date]mélange de concentrés de plaquettes - mcp [date]cgr unité adulte ( 257 - 297 ml ) [date]cgr unité adulte ( 257 - 297 ml ) [date]cgr unité adulte ( 257 - 297 ml ) [date]cgr unité adulte ( 257 - 297 ml ) [date]concentre de plaquettes d ' apherese cpa [date]concentre de plaquettes d ' apherese cpa [date]mélange de concentrés de plaquettes - mcp [date]cgr unité adulte ( 257 - 297 ml ) [date]cgr unité adulte ( 257 - 297 ml ) [date]mélange de concentrés de plaquettes - mcp [date]mélange de concentrés de plaquettes - mcp [date] resume de l ' hositalisation : patiente de 57 ans hospitalisée pour début de prise en charge d ' une lal phi +
# motif d ' admission : patiente de 57 ans hospitalisée pour début de prise en charge d ' une lal phi +
# antecedents :
# 1 ) médicaux
# \- hta , traitée par candesartan
# \- lombalgie
# \- surdité partielle od
# \- coxarthrose
# 2 ) chirurgicaux
# \- chirurgie de l ' humerus droit
# \- appendicectomie
# 3 ) familiaux :
# \- leucémie aigüe chez la mère
# \- cancer du pancréas chez le frère
# \- cardiopathie chez la sœur
# allergies :
# \- pénicillines et voltarene ( notion d ' angio - oedemes )
# \- graminés
# toxiques :
# \- tabac : 5 cigarettes / jour depuis plusieurs années
# \- alcool : 1 verre à chaque repas
# traitement habituel :
# \- candesartan
# \- tramadol
# \- kestin pour sa rhinite
# mode de vie :
# vit avec son mari , sans enfants , parfaitement autonome à domicile et travaille comme saisonnière en agriculture . notion d ' exposition au nickel et au cobalt lors de son précédent travail dans une bijouterie ( eczéma corps entier avec arrêt de travail pendant 1 an ) .
# fratrie : neuf frères et sœurs dont les coordonnées ont été recueillies , un est atteint d ' anévrysme sans précision , et un autre de maladie de parkinson .
# histoire de la maladie :
# la patiente consulte aux urgences du centre hospitalier de valence le [date] pour des douleurs abdominales prédominant en fosse iliaque gauche , apparues une semaine avant , associé à une asthénie intense et perte de 6 kg en 1 mois sans régime . elle est stable sur le plan hémodynamique , apyrétique . la bio met en évidence une hyperleucocytose à 350 g/l avec une blastose importante faisant poser le diagnostic de leucémie aigüe , un acide urique à 380 mmol/l et une kaliémie à 6 . 9 mmol/l sans signe électriques à l ' ecg . elle reçoit un traitement par salbutamol , kayexalate , insuline glucose et hyperhydratation et est transférée en réanimation au pavillon h de heh .
# durant son séjour à heh : contrôle de l ' hyperuricémie avec une dose de fasturtec . sur le plan pulmonaire , un scan thoracique retrouve des condensation bi - basales d ' allures infectieuses avec une lame d ' épanchement pleural bilatéral motivant un début d ' atb par cefotaxime et recherche de grippe qui s ' avère négative . devant ces douleurs abdominales intenses , un tdm - tap est réalisé retrouvant une splénomégalie homogène , pas de complication abdominale notamment pancréatique et digestive , ni d ' adp profonde . episode de surcharge hydrosodée post hyperhydratation sur prévention d ' un syndrome de lyse . a la fin du séjour : k+ à 4 . 8 , hb : 81 , plt : 43 , créat ' à 64 , bilan de coag ' normal ( tp : 73 % tca à 0 . 99 et fibrinogène à 5 . 24 ) . immunophénotypage en raison d ' une lal avec phi+
# transfert du 2bs le 06/03 pour la suite de la prise en charge .
# examen du patient a l ' admission
# poids : 63 kg taille : 156 cm ps 2 apyrétique
# sur le plan cardiaque : bdc réguliers , sans bruits surajoutés , pas de signe de tvp , rhj , tj , pas d ' omi
# sur le plan pulmonaire : murmure vésiculaire bilatéraux et symétriques , fin crépitant aux bases , pas de dyspnée en aa , toux grasse depuis quelques jours à priori
# sur le plan abdominal : pas d ' organomégalie . palpation sensible ( hypochondre droit + épigastre ++ ) , la patiente se plaint d ' une douleur en barre au niveau épigastrique ( scanner normal fait en réa , mais patiente très angoissée ) . transit ok
# sur le plan thymique : patiente très angoissé demandeuse de traitements . elle ne désire pas voir de psychologue pour l ' instant .
# sur le plan cutanée : ras
# pas de sfu
# aires ganglionnaires libres
# biologie a l ' admission : bilan du 06/03
# nfp : gb : 293 g/l pnn : 8 . 81 g/l ly : 8 . 81 g/l hb : 84 g/l plq : 38 g/l blastes : 94 %
# coagulation : ratio tca 0 . 84 tp 73 % inr 1 . 24 fibronogène 5 . 77g/l
# ionogramme : sodium 138 potassium 3 . 1 chlore 104 bicarbonates 23
# albumine 32g/l
# créatinine/mdrd : 67 µmol/l dfg 87ml/min
# bilan hépatique normal / ldh 828 :
# crp : 185
# ferritine : 1654
# sérologies vih , vha , vhb , vhc , ebv , cmv , hsv :
# anticorps igg anti - vca et igg anti - ebna positifs , tous les autres sont négatifs ( notamment pas de contact avec le vhb , ni vaccination )
# bilan diagnostique ( date )
# myélogramme : non réalisé compte - tenu de la blastose sanguine
# bilan pre - therapeutique
# ecg : rythme sinusal régulier , tracé sans particularité
# ett : non réalisé dans un premier temps
# rp : sans particularité en dehors d ' une distension thoracique avec horizontalisation des côtes , et émoussement du cul de sac pleural bilatéral
# pose de vvc ( type et date ) : pose d ' un picc line le 09/03
# groupage hla : o rh positif ( rh : 1 )
# cecos : non réalisé
# nb : mise en évidence d ' une infiltration méningée de la leucémie le 10/03
# protocole de chimiotherapie ( préciser si patient inclus dans un protocole )
# rcp : le 10/03 , validation de l ' inclusion dans l ' essai national graaph
# date du début : préface de corticoïdes à partir du 08/03 , puis début du protocole le 16/03
# molécules :
# \- ec nilotinib 400 mg ( j1 [date] )
# \- ec nilotinib 400 mg ( j1 [date] )
# \- vincristine 2 mg ( j1 [date] )
# \- ec nilotinib 400 mg ( j2 [date] )
# \- ec nilotinib 400 mg ( j2 [date] )
# \- aracytine 40 mg ( j8 [date] )
# \- hydrocortisone 40 mg ( j8 [date] )
# \- methotrexate intrat 15 mg ( j8 [date] )
# \- ec nilotinib 400 mg ( j8 [date] )
# \- vincristine 2 mg ( j8 [date] )
# \- ec nilotinib 400 mg ( j9 [date] )
# \- ec nilotinib 400 mg ( j1 [date] )
# \- ec nilotinib 400 mg ( j1 [date] )
# \+ pl simple le 10/03 , et triple les 16/03 et 23/03 :
# \- methotrexate intrat 15 mg ( j1 10/03/2020 )
# evolution durant le sejour
# hématologique :
# administration du premier cycle de chimiothérapie à partir du 16/03 :
# \- aracytine 40 mg ( j1 [date] )
# \- hydrocortisone 40 mg ( j1 [date] )
# \- methotrexate intrat 15 mg ( j1 [date] )
# \- vincristine 2 mg ( j1 [date] )
# \- aracytine 40 mg ( j8 [date] )
# \- hydrocortisone 40 mg ( j8 [date] )
# \- methotrexate intrat 15 mg ( j8 [date] )
# \- vincristine 2 mg ( j8 [date] )
# \- vincristine 2 mg ( j15 [date] )
# \- vincristine 2 mg ( j22 [date] )
# ponction lombaire diagnostique ( et injection de methotrexate ) le 10/03 envahie .
# la chimiothérapie intrathécale a été administrée au j1 ( 16/03 ) et au j8 ( 23/03 ) uniquement : des céphalées apparues au décours du j8 on fait réaliser un scanner cérébral ( 27/03 ) qui retrouvait un hématome sous - dural bilatéral . le scanner a été contrôlé une semaine plus tard , et trois semaines plus tard : persistance de l ' hsd bilatéral avec signes de saignement récent . on contre - indique donc les ponctions lombaires , et on maintien un taux de plaquettes > 50g/l . les céphalées se sont peu à peu amendées grâce au tramadol et à la corticothérapie ( un avis neurochirurgical avait été pris auprès de [doctor] du médipôle )
# bilan médullaire le 14/04 , avant d ' initier le deuxième cycle :
# \- cytologie : prélèvement médullaire où l ' on observe de rares cellules immatures ( < 1 % ) dont le caractère blastique est à confronter au résultat du bilan complémentaire . aspect de rémission cytologique .
# \- biologie moléculaire : bcr \- abl 6 . 1 % dans la moelle , 3 % dans le sang
# administration du 2ème cycle à partir du 15/04 :
# \- methotrexate 1500 mg ( j1 [date] )
# \- aracytine 2300 mg ( j2 [date] )
# \- aracytine 2300 mg ( j2 [date] )
# \- aracytine 2300 mg ( j3 [date] )
# \- aracytine 2300 mg ( j3 [date] )
# ce deuxième cycle a été compliqué d ' une toxicité hépatique ( cytolyse et cholestase anictérique , avec échographie et scanner retrouvant une dilatation des voies biliaires intra - hépatiques , sans signe en faveur d ' une maladie veino occlusive ) et d ' une insuffisance rénale aigue , avec retard à l ' élimination du méthotrexate , de correction rapide après suspension des médicaments néphro - et hépato - toxiques .
# dans ce contexte , le nilotinib a été suspendu du 20/04 au 24/04 .
# on note une normalisation des bilan hépatiques et rénaux le 27/04 .
# o date pnn < 0 , 5g/l : 19/04 pour le deuxième cycle
# o date pnn > 0 , 5g/l : 01/04 pour la premier cycle
# o date plq > 20 g/l : plaquettes maintenues > 50g/l
# sortie d ' aplasie le [date] pour le second cycle , permettant de réaliser un nouveau bilan médullaire le [date] :
# \- cytologie : myélogramme correspondant à une persistance de la rémission cytologique avec une bonne représentation des différentes lignées myéloïdes .
# \- immunophénotypage :
# persistance d ' une mrd2 de la lalb connue ( estimée à 0 , 5 % soit 5x10 - 3 de la cellularité totale ) , avec globalement le même profil antigénique que celui du diagnostic : cd34+cd38+/ - cd19+cd10++cd20 - cd58++ .
# \- biologie moléculaire :
# transcrits bcr - abl1 major en diminution à 0 . 69 % dans la moelle , au lieu de 6 % précédemment .
# o transfusions : type de produits / nb de cgr/ nb de cpa/ nb de mcp/nb de pfc
# infectiologique :
# o antibiotiques ( avec les dates ) :
# administration de pentacarinat préventif le 10/03
# zyvoxid du 08/03 au 21/03 sans documentation pour veinite des deux membres supérieurs
# tazocilline du 14/03 au 16/03 en traitement d ' une angine , puis à partir du 20/03 dans le cadre du protocole graaf
# 07/04 : arrêt de la tazocilline protocolaire
# 18/04 : reprise tazocilline pour aplasie fébrile , et devant la fièvre persistante et la mise en évidence d ' un foyer de crépitants en base gauche , de ciprofloxacine .
# la ciprofloxacine est arrêtée à 48h devant une réaction cutanée , qui peut également être imputable à l ' aracytine , et n ' est pas reprise
# le 20/04 , arrêt de la tazocilline devant la perturbation du bilan hépatique , remplacée par la céfépime .
# le 27/04 , nouvel épisode d ' aplasie fébrile , sous axepim flagyl , d ' évolution favorable .
# mise en évidence d ' un zona thoracique droit le 29/04 , d ' évolution favorable sous aciclovir intraveineux ( dose de charge puis d ' entretien )
# sortie d ' aplasie le 05/05 , permettant un arrêt progressif des antibiotiques , sans récidive fébrile .
# o documentations :
# bactériologiques :
# \- hémocultures négatives jusqu ' au 13/05
# \- ecbu positif à candida puis e coli , sans symptômes donc pas de traitement spécifique .
# \- bmr de type hafnia dans les prélèvements de gorge réalisés à titre systématique .
# mycologiques : aucune au 13/05
# virologiques : aucune au 13/05
# parasitologiques : aucune au 13/05
# o lba ( si réalisé )
# métaboliques :
# o evolution du poids ( +/ - alimentation artificielle ) : dénutrition modérée en raison d ' une perte de poids de plus de 10 % en 6 mois . conseils nutritionnels par la diététicienne du clb .
# au 16/04 , avant le début du deuxième cycle , poids de 53 kg , soit une perte de poids de 10kg . indication théorique de nutrition artificielle , non instaurée dans un premier temps du fait de la mucite et de la perturbation du bilan hépatique . finalement , pose de sonde nasogastrique le [date] , avec augmentation progressive des apports , avec une bonne tolérance jusqu ' à 1500ml/24h à une vitesse de 200ml/heure , sans syndrome de renutrition inapproprié .
# on décide de retirer la sonde nasogastrique le 13/05 , lors de la sortie d ' hospitalisation , la patiente retrouvant un bon appétit . on discutera une nouvelle pose le 25/05 lors de son retour .
# o fonction rénale : épisode d ' insuffisance rénale aigue après l ' administration du deuxième cycle , imputée au methotrexate , résolutif ( autour du 22/04 ) . pas de nouvelle perturbation de la fonction rénale jusqu ' à la sortie .
# o fonction hépatique : toxicité hépatique ( cytolyse et cholestase anictérique , avec échographie et scanner retrouvant une dilatation des voies biliaires intra - hépatiques , sans signe en faveur d ' une maladie veino occlusive ) , autour du 22/04 , résolutif avec le temps et la suspension des médicaments hépatotoxiques . pas de nouvelle perturbation de la fonction hépatique jusqu ' à la sortie .
# o digestive :
# réalisation d ' une échographie abdominale le 11/03 devant des douleurs :
# absence de foyer infectieux profond décelé sur cet examen . hépatomégalie homogène . épanchement pleural bilatéral de faible abondance .
# constipation importante autour du 08/04 associée à des douleurs abdominales , ayant cédé après l ' administration de xprep
# scanner abdomino - pelvien le 08/04 : stase stercorale du cadre colique , marquée au niveau du cæcum .
# nausées ( grade ) : 2
# mucite ( grade ) : le 20/04 , mise en évidence d ' une mucite de grade 3 ayant motivé l ' introduction d ' une pca d ' oxynorm et de fluconazole topique . amélioration progressive des lésions avec la sortie d ' aplasie , permettant un sevrage progressif de la pca .
# diarrhées ( grade ) : absence
# autres : sur le plan neurologique :
# ponction lombaire diagnostique ( et injection de methotrexate ) le 10/03 envahie .
# la chimiothérapie intrathécale a été administrée au j1 ( 16/03 ) et au j8 ( 23/03 ) uniquement : des céphalées apparues au décours du j8 on fait réaliser un scanner cérébral ( 27/03 ) qui retrouvait un hématome sous - dural bilatéral . le scanner a été contrôlé une semaine plus tard , et trois semaines plus tard : persistance de l ' hsd bilatéral avec signes de saignement récent . on contre - indique donc les ponctions lombaires , et on maintien un taux de plaquettes > 50g/l . les céphalées se sont peu à peu amendées grâce au tramadol et à la corticothérapie ( un avis neurochirurgical avait été pris auprès de [doctor] du médipôle )
# pour rappel , on a surveillé à plusieurs reprises le scanner cérébral :
# \- le 27/03 : hématome sous - dural aigu frontopariétal bilatéral prédominant à droite sur hématome sous - dural chronique . lame d ' hématome sous - dural parafalcoriel et de la tente du cervelet .
# \- le 06/04 : lames d ' hématome sous - dural chronique frontopariétales bilatérales prédominant à gauche ( 8 mm d ' épaisseur maximale en frontal gauche ) . aspect plus dense de l ' hématome frontaopariétal droit en faveur d ' un nouveau saignement .
# \- le 20/04 : à l ' étage cérébral , diminution en taille des hématomes sous - duraux des deux convexités . par contre , réapparition d ' une hyperdensité spontanée au sein du décollement sous - dural de la convexité gauche en faveur d ' un resaignement aigu .
# \- le 04/05 : majoration de l ' hématome sous - dural hémisphérique gauche avec signe de resaignement en son sein , responsable d ' un effet de masse sur les structures médianes , déviées vers la droite de 5 mm . majoration également de l ' hématome sous - dural postérieur droit , sans signe de resaignement .
# \- le 11/05 : stabilité de l ' hématome sous - dural chronique hémisphérique gauche avec déviation de la ligne médiane de 3 mm contre 5 mm précédemment . majoration en taille de l ' hématome sous - dural pariéto - occipital droit , partiellement cloisonné de 15 mm d ' épaisseur maximale contre 12 mm précédemment .
# on conclut donc à une persistance de l ' hématome malgré maintien d ' un seuil plaquettaire > 50g/l pendant toute la durée de l ' hospitalisation , nous empêchant de répéter les ponctions lombaires , la dernière ( 23/03 ) étant envahie .
# a noter , deux épisdoes de rectorragies de faible abodance le 13/05 , sans déglobulisation ni anomalie à l ' inspection de la marge anale et du toucher rectal , qui nous font demander une rectosigmoidoscopie pour la prochaine hospitalisation .
# sur le plan hématologique , on décide de prendre un avis auprès du centre expert pour la suite de la conduite à tenir .
# le bon état clinique et psychologique de la patiente permettent un retour à domicile le 14/05 . elle sera convoquée le 25/05 pour la suite du traitement .
# bilan a la sortie
# lieu : domicile
# bilan médullaire : myélogramme répété le 06/05 :
# \- cytologie : myélogramme correspondant à une persistance de la rémission cytologique avec une bonne représentation des différentes lignées myéloïdes .
# \- immunophénotypage :
# persistance d ' une mrd2 de la lalb connue ( estimée à 0 , 5 % soit 5x10 - 3 de la cellularité totale ) , avec globalement le même profil antigénique que celui du diagnostic : cd34+cd38+/ - cd19+cd10++cd20 - cd58++ .
# \- biologie moléculaire :
# transcrits bcr - abl1 major en diminution à 0 . 69 % dans la moelle , au lieu de 6 % précédemment .
# programme thérapeutique : sera reconvoquée le [date] pour la suite du traitement
# traitement de sortie :
# candesartan/ hctz 8 mg/12 . 5 mg ( candesartan/hctz 8 mg/12 , 5mg cpr ) , voie orale , 1 comprime ( s ) 1 fois dans la journée
# ec nilotinib , gelule , voie orale , 400 mg 2/j à 07 : 00 , 19 : 00 pendant 1 mois
# a prendre à distance des repas avec un grand verre d ' eau .
# aucun aliment ne doit être consommé pendant les 2 heures précédant la prise du médicament et pendant 1 heure au moins après celle - ci .
# respecter un intervalle de 12 heure entre les prises .
# artisial ( artisial sol ) , voie buccale , 1 flacon ( s ) pressurise ( s ) 8 - 12 - 18h pendant 1 mois
# pour les nausées :
# \- primperan 10 mg : 1 prise en cas de nausées/vomissements , maximum 3 prises par jour , intervalle minimum
# entre 2 prises de 6 heures
# pour la prévention des infections :
# \- zelitrex 500mg : 1 comprimé matin et soir
# pour la prévention des mucites :
# \- bains de bouche 6 fois par jour avec : bicarbonate 1 . 4 % 250ml ( un flacon par jour )
# pour l ' estomac :
# \- eupantol 20mg : 1 comprimé par jour
# pour les douleurs :
# \- topalgic 50mg : 1 prises en cas de douleurs , maximum 3 prises par jour , intervalle minimum entre 2 prises de 6
# heures
# \- si persistance : ampoule de néfopam 20mg , jusqu ' à trois fois par jour , à boire
# pour la constipation :
# \- forlax sachet : 2 sachets le matin au départ puis 1 sachet matin et soir . si persistance de la constipation , 6 sachets
# par jour maximum .
# 07/03/20 corbaux ( idg°
# veinite bilatérale aux avant bras stables , apyrétique mauvaise tolérance osmogel \- - > application de froid et antalgiques paliers 1 et 2
# douleurs abdominales diffuses persistantes abdomen souple - - > spasfon
# as michallet 07 . 03 et 08 . 03
# 2 éléments :
# \- majoration de l ' essouflement sans nécesisté d ' une oxygénothérapie majorée \- corticothérapie débutée ce jour 1 mg/kg
# \- douleur majeur au niveau des 2 bras avec aspect erythème et empatement - mise en place d ' une atb à tropisme peux + tissus sous cutanée par zyvoxid \+ pries en charge symptomatique
# chardon 10/03/20 idg
# apres 10 minutes de pentacarinate sensation d ' etouffement de brulure au niveau des bronche d ' après elle patiente fc 105 ta 196/103 désaturation a 85 % , normalisation sous 7l o2 a 94 % pour une normale a 91 % chez cette patiente .
# contrôle ta 18/9 fc 90 sat 92 % sous 4l
# a mon arrivée patiente spastique au niveau respiratoire avec sibilant diffus , bdc régulier pas de souffle perçu , pas de marbrure pas d ' hypotension , pas d ' œdème laryngé
# hyperventilation \- > aérosol de salbutamol \+ polaramine avec une nette amélioration des symptômes
# de principe dosage des tryptases + car épisode arrivé après 10 minutes de passage de l ' aérosol
# épisode d ' hypothermie 35 . 5 hemoc + ecbu de principe
# 11/03 laurine figaro ( externe )
# apyrétique , ta 184/100 , fc 84bpm
# epps : profil inflammatoire
# ecbu du 10/03 stérile
# examen clinique sans particularité
# la patiente se plaint de selles de couleur inhabituelle ( jaunes )
# 12/03 laurine figaro ( externe )
# apyrétique , ta 164/110 , fc 83
# ecbu du 10/03 : 10^3 d ' e . coli
# bio : hb 84g/l vs 68 hier , gb 167g/l vs 238 hier , plaquettes 44g/l vs 63 hier
# pas de crp disponible ce jour
# la patiente s ' est plainte de 2 réveils nocturnes
# > 1er réveil aux alentours de 2 ou 3h : dyspnée ayant nécessité o2 + aérosols
# a l ' examen , patiente qui ne se plaint pas de dyspnée mais essoufflée au repos nyha iv
# crépitants aux bases , pas de signe d ' icd , pas de céphalée , pas de vertige
# toux majorée depuis lundi , glaires non expectorées
# douleur péri - ombilicale sans irradiation déjà explorée à l ' écho ( normale )
# reste de l ' examen clinique sans particularité ( pas de sfu )
# 23/03 guillermin
# j8 protocole graaph .
# pl du j1 encore envahie
# pl triple faite ce jour
# va bien par ailleurs
# sous tazo protocolaire devant pnn < 0 . 5 , apyrétique
# 24/03 polito
# va bien
# douleurs légères de sinusite motivant la prescription d ' aerosol de serum phy
# résultats de la pl : infiltré
# 25/03 polito
# va bien
# 26/03 polito
# va bien - quelques céphalées persistantes ( une pl par semaine , toujours envahie )
# examen clinique sans particularité par ailleurs , pas de point d ' appel infectieux
# 27/03 polito
# persistance céphalées + un épisode de vomissements ce matin
# on demande scanner cérébral > hypotension intracrânienne ? on demande scanner cérébral >
# on demande scanner cérébral >
# résultat = hématome sous - dural aigu frontopariétal bilatéral prédominant à droite sur hématome sous - dural chronique . lame d ' hématome sous - dural parafalcoriel et de la tente du cervelet .
# absence d ' engagement
# on prend un avis neurochirurgical auprès d ' anne durand :
# \- pas d ' indication neurochirurgicale
# \- traitement symptomatique par corticoïdes 1mg/kg pendant quelques jours
# \- pas de nouvelle pl tant que les céphalées persistent
# amélioration clinique ( céphalées \+ vomissements ) dans l ' après - midi
# 29/03 guillermin
# ...
# apres 10 minutes de N=C(N)C1CCC(OCCCCCOC2CCC(C(=N)N)CC2)CC1e sensation d ' etouffement de brulure au niveau des bronche d ' apres elle patiente fc 105 ta 196/103 desaturation a 85 % , normalisation sous 7l o2 a 94 % pour une normale a 91 % chez cette patiente .
# controle ta 18/9 fc 90 sat 92 % sous 4l
# a mon arrivee patiente spastique au niveau respiratoire avec sibilant diffus , bdc regulier pas de souffle percu , pas de marbrure pas d ' hypotension , pas d ' oedeme larynge
# hyperventilation \- > aerosol de CC(C)(C)NCC(O)C1=CC(CO)=C(O)C=C1 \+ CN(C)CC[C@@H](C1CCC(CL)CC1)C1CCCCN1.O=C(O)/C=C\C(=O)O avec une nette amelioration des symptomes
# de principe dosage des tryptases + car episode arrive apres 10 minutes de passage de l ' aerosol
# episode d ' hypothermie 35 . 5 hemoc + ecbu de principe
# 11/03 laurine figaro ( externe )
# apyretique , ta 184/100 , fc 84bpm
# epps : profil inflammatoire
# ecbu du 10/03 sterile
# examen clinique sans particularite
# la patiente se plaint de selles de couleur inhabituelle ( jaunes )
# 12/03 laurine figaro ( externe )
# apyretique , ta 164/110 , fc 83
# ecbu du 10/03 : 10^3 d ' e . coli
# bio : hb 84g/l vs 68 hier , gb 167g/l vs 238 hier , plaquettes 44g/l vs 63 hier
# pas de crp disponible ce jour
# la patiente s ' est plainte de 2 reveils nocturnes
# > 1er reveil aux alentours de 2 ou 3h : dyspnee ayant necessite o2 + aerosols
# a l ' examen , patiente qui ne se plaint pas de dyspnee mais essoufflee au repos nyha iv
# crepitants aux bases , pas de signe d ' icd , pas de cephalee , pas de vertige
# toux majoree depuis lundi , glaires non expectorees
# douleur peri - ombilicale sans irradiation deja exploree a l ' echo ( normale )
# reste de l ' examen clinique sans particularite ( pas de sfu )
# 23/03 guillermin
# j8 protocole graaph .
# pl du j1 encore envahie
# pl triple faite ce jour
# va bien par ailleurs
# sous tazo protocolaire devant pnn < 0 . 5 , apyretique
# 24/03 polito
# va bien
# douleurs legeres de sinusite motivant la prescription d ' aerosol de serum phy
# resultats de la pl : infiltre
# 25/03 polito
# va bien
# 26/03 polito
# va bien - quelques cephalees persistantes ( une pl par semaine , toujours envahie )
# examen clinique sans particularite par ailleurs , pas de point d ' appel infectieux
# 27/03 polito
# persistance cephalees + un episode de vomissements ce matin
# on demande scanner cerebral > hypotension intracranienne ? on demande scanner cerebral >
# on demande scanner cerebral >
# resultat = hematome sous - dural aigu frontoparietal bilateral predominant a droite sur hematome sous - dural chronique . lame d ' hematome sous - dural parafalcoriel et de la tente du cervelet .
# absence d ' engagement
# on prend un avis neurochirurgical aupres d ' anne durand :
# \- pas d ' indication neurochirurgicale
# \- traitement symptomatique par corticoides 1mg/kg pendant quelques jours
# \- pas de nouvelle pl tant que les cephalees persistent
# amelioration clinique ( cephalees \+ vomissements ) dans l ' apres - midi
# 29/03 guillermin
# cephalees tres nettement ameliorees ce jour , hier mise sous COC1=CC=CC(=C1)C1(O)CCCCC1CN(C)C lp . effet des ctc probable . ras par ailleurs
# 30/03 polito
# amelioration des cephalees , mais on ne realise pas de pl ce jour
# hypoerbilirubinemie apparue ce jour , mentionnee dans les effets indesirables frequents du CC1=CN(C=N1)C1=CC(NC(=O)C2=CC=C(C)C(NC3=NC=CC(=N3)C3=CN=CC=C3)=C2)=CC(=C1)C(F)(F)F > on realise un dosage sanguin du CC1=CN(C=N1)C1=CC(NC(=O)C2=CC=C(C)C(NC3=NC=CC(=N3)C3=CN=CC=C3)=C2)=CC(=C1)C(F)(F)F
# pas de cytolyse hepatique associee
# 31/03/20 ( rey ) : j16 graaph/j3 CC1=CN(C=N1)C1=CC(NC(=O)C2=CC=C(C)C(NC3=NC=CC(=N3)C3=CN=CC=C3)=C2)=CC(=C1)C(F)(F)F bon etat clinique malgre les cephalees et cervicalgies absence de trouble digestif examen somatique normal biologie correcte , neutropenie 0 . 39 g/l , plq 77 g/l dosage de CC1=CN(C=N1)C1=CC(NC(=O)C2=CC=C(C)C(NC3=NC=CC(=N3)C3=CN=CC=C3)=C2)=CC(=C1)C(F)(F)F en attente
# 02/04 polito
# va bien - persistance cephalees motivant reintroduction de corticoides type C[C@H]1C[C@@H]2[C@H]([C@@H](O)C[C@@]3(C)[C@H]2CC[C@]3(O)C(=O)CO)[C@@]2(C)C=CC(=O)C=C12 iv 40mg par jour
# nouvelle baisse des pnn a 0 . 34g/l ce jour : retard a la sortie d ' aplasie
# 04 et 05 . 04 as michallet
# aucun probleme specifique ce we
# non cephalagique
# pas de syndrome hemorragique
# auscultation pulmonaire parfaite
# 13h : expulsion d ' un verre de 15 cm ! envoi en parasito
# 06/04 polito
# controle du scanner cerebral ce jour pour evaluer possibilite de reprise pl > lame d ' hematome sous - dural aigue de 4 mm au contact de la partie posterieure de la faux du cerveau et millimetrique au contact de la tente du cervelet + les amygdales cerebelleuses affleurent toujours le foramen magnum
# amelioration des cephalees par ailleurs
# 07/04 polito
# appel anne durand hier soir : pas de reprise des pl pour le moment , reevaluer le scanner dans 15 jours - stimuler la boisson pour accelerer resorption hematome
# sortie d ' aplasie avec pnn > 0 . 5 depuis deux jours - arret isolement protecteur
# tasinia sous - dose sur le prelevement du 30/03 , rendu le 06/04 : residuel a 0 . 55ui/l au lieu de 0 . 9 > on recherche dans protocole la conduite a tenir
# poursuite C[C@]1(CN2CCNN2)[C@H](C(=O)[O-])N2C(=O)C[C@H]2S1(=O)=O.[NA+] protocolaire ?
# par ailleurs la suspicion de parasitose intestinale a ete infirmee par le laboratoire de parasitologie : glaires - on poursuit tout de meme le deparasitage
# 08/04 guillermin
# toujours douloureuse au niveau abdo malgre selles ++ lundi apres xprep . nous signal avoir fait un episode de sigmoidite il y a 2 ans avec symptomes similaires , vu sur echo abdo et traite par CC1=NC=C(N1CCO)[N+]([O-])=O par mt .
# effectivement a la palpation , signe de blumberg et douleurs en fig et dte . cicatrice d ' appendicectomie . pas de defense . pas de sfu .
# reste de l ' examen sans particularite .
# \- - > demande de scanner , mise a jeun = stase stercorale de l ' ensemble du cadre colique
# 09/04 polito
# douleurs abdominales au premier plan > traitement symptomatique + poursuite des laxatifs
# nausees \+ mucide candidosique > CC1NCCN1CC1CCC2C(C3CCCCC3N2C)C1=O \+ C[C@@H]1[C@H](O)[C@@H](C)/C=C/C=C/C=C/C=C/C=C/C=C/C=C/[C@H](O[C@@H]2O[C@H](C)[C@@H](O)[C@H](N)[C@@H]2O)C[C@@H]2O[C@](O)(C[C@@H](O)C[C@@H](O)[C@H](O)CC[C@@H](O)C[C@@H](O)CC(=O)O[C@H]1C)C[C@H](O)[C@H]2C(=O)O en complement du traitement habituel
# recidive des cephalees apres arret des corticoides > reprise COC1=CC=CC(=C1)C1(O)CCCCC1CN(C)C lp ce jour , revoir pour reintroduire les corticoides demain
# 11/04 polito
# selles profuses ce matin apres xprep - emission d ' un comprime , non identifie
# douleurs abdominales persistantes , mais abdomen souple , non meteorise
# cephalees persistantes egalement , moderees
# leucocytes 1 . 81g/l , hb 8g/dl , plaquettes 219 g/l
# myelogramme du 14/04 :
# cytologie : prelevement medullaire ou l ' on observe de rares cellules immatures ( < 1 % ) dont le caractere blastique est a confronter au resultat du bilan complementaire . aspect de remission cytologique .
# biologie moleculaire : transcrits bcr - abl1 major en diminution a 6 . 1 %
# 16/04 polito
# va bien , un peu endormie ce matin mais facilement reveillable
# 17/04 maugeais ( idg )
# appel pour hyperthermie 38 . 2 bonne tolerance hemodynamique pas de marbrure pas de signes de lutte
# glascow 15
# ex cv : tachycardie reguliere pas de souffle mollets souples et indolores
# ex pulmo : mv bilat et symetrique pas de foyer eupneique en aa
# abdomen souple mais douleur a la palpation
# pnn : 1 - > cpr en hausse de 7015/04 a 132 17/04
# pas de sfu pas de diarrhee toux avec glaires
# reprise C[C@]1(CN2CCNN2)[C@H](C(=O)[O-])N2C(=O)C[C@H]2S1(=O)=O.[NA+] \+ controle crp demain
# 19/04 polito idg
# appel pour fievre avec desaturation
# introduction C[C@]1(CN2CCNN2)[C@H](C(=O)[O-])N2C(=O)C[C@H]2S1(=O)=O.[NA+] il y a 24 h - entree en aplasie ce jour - bonne hemodynamique
# cliniquement rassurante , eupneique et sat 97 % sous 2l
# foyer de crepitants en base gauche
# pas d ' autre point d ' appel clinique
# devant ce tableau d ' aplasie febrile sous C[C@]1(CN2CCNN2)[C@H](C(=O)[O-])N2C(=O)C[C@H]2S1(=O)=O.[NA+] , avec poursuite de l ' ascension de la crp ( plus de 300 ce jour ) , j ' introduis OC(=O)C1=CN(C2CC2)C2=CC(N3CCNCC3)=C(F)C=C2C1=O 400mgx2/jour
# 20/04 [doctor]
# j6 cycle 2 graaph 2014
# apyretique sous tazo - CL.O=C(O)C1CN(C2CC2)C2CC(N3CCNCC3)C(F)CC2C1=O mais crp tres eleve a 330 mg/l
# mucite avec depots - > ajout OC(CN1C=NC=N1)(CN1C=NC=N1)C1=C(F)C=C(F)C=C1 \+ pca COC1CCC2C3C1O[C@H]1C(=O)CC[C@@]4(O)[C@@H](C2)N(C)CC[C@]314.CL pour les douleurs
# perturbation bh de type cholestase \- > suspension nilo
# tp effondre a 41 % avec facteur v > 150 - > probable carence en vit k + role du sd inflammatoire - > suplementaion en vit k
# retard elimination mtx a 0 . 55 a h72 - > poursuite levofo avec montee dose a 100 mg/6h , creat stable a 100 ( cl 52 ml/mn )
# tdm ctap ce jour : diminution hsd mais signe de resaignement actif , qqs images en verre depoli peu specifiques ( possible surcharge sous hydrat du mtx ) , aspect de dilatation des vbih/vbeh - > controle echo demande
# enfin , picc qui s ' est retire de pls cm - > changement voie sur guide demande
# 20/4 dekeister mdg
# appel 21h30 pour eruption cutanee
# eruption ayant debute ce matin aux 2 pieds prurigineuse , ce soir prrit etendu a l ' abdomen , dos et sacrum avec lesion cutanees en regard , plaques erythemteuses avec papules , intervalles libres , ne disparait pas a la vitropression
# patiente allergique peni O=C([O-])CC1CCCCC1NC1C(CL)CCCC1CL.[NA+]
# ( oedemes q )
# constantes ok
# = > delimitation lesions , pola 1 ampoule
# introduction medicaments recent : tazo j[date]s reprise , en a deja eu en mars/ CL.O=C(O)C1CN(C2CC2)C2CC(N3CCNCC3)C(F)CC2C1=O j2 debute hier matin , 3e prise ce matin , prochaine a 20h , OC(CN1C=NC=N1)(CN1C=NC=N1)C1=C(F)C=C(F)C=C1 debute ce midi
# = > + probable = CL.O=C(O)C1CN(C2CC2)C2CC(N3CCNCC3)C(F)CC2C1=O : suspension , a revoir demain , si pas d ' amelioration ou extension fluco ? autre ?
# 21/04 polito
# sur le plan clinique :
# \- mucite grade 3 mieux supportee grace a la pca d ' COC1=C2O[C@H]3C(=O)CC[C@@]4(O)[C@H]5CC(C=C1)=C2[C@@]34CCN5C
# \- prise de poids notable malgre la depletion ( 7kg en 5 jours ) + hepatomegalie douloureuse
# \- poids veritable probablement de 53 - 55kg , soit une perte de poids de 10kg sur l ' ensemble du sejour , avec difficulte de renutrition orale > indication nutrition artificielle evoquee par la dieteticienne
# \- resolution de l ' eruption cutanee decrite la nuit derniere
# \- transit regulier
# sur le plan biologique
# \- poursuite perturbation bilan hepatique , aussi bien sur le versant cytolytique que cholestatique
# \- tableau d ' insuffisance renale aigue persistante
# \- bilan de coagulation en cours
# > suspicion clinique et biologique de maladie veino - occlusive veineuse > echo doppler hepatique avec protocole specifique demandee
# > aplasie , sans nouvel episode de fievre , actuellement sous C[C@]1(CN2CCNN2)[C@H](C(=O)[O-])N2C(=O)C[C@H]2S1(=O)=O.[NA+] et OC(CN1C=NC=N1)(CN1C=NC=N1)C1=C(F)C=C(F)C=C1 uniquement > a surveiller
# l . lebras le 22/04
# * mucite en amelioration , persistance cheilite
# * apyretique mais persistance syndrome inflammatoire biologique majeure : virus en cours et ag aspergillaire et b glucanes
# tdm ctap sans argument pour un foyer infectieux
# igiv en cas de cause virale
# * amelioration du bilan hepatique depuis arret CC1=CN(C=N1)C1=CC(NC(=O)C2=CC=C(C)C(NC3=NC=CC(=N3)C3=CN=CC=C3)=C2)=CC(=C1)C(F)(F)F/ switch tazo au profit de CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[N+]3(C)CCCC3)CS[C@H]12)C1CSC(N)N1
# doppler pas d ' argument pour une mvo
# * CN(CC1=CN=C2N=C(N)N=C(N)C2=N1)C1=CC=C(C=C1)C(=O)N[C@@H](CCC(O)=O)C(O)=Omie a 0 . 29 a h96 , nouveau dosage ce jour = > poursuite hyperhydrat alacaline et folinate
# * + 7 kg = > diuretisation
# * sur le plan respi , sat a 98 % sous 4 l
# 23/04 guillermin
# * du point de vue de la mucite : re aggravation ce jour surtout du point de vue des douleurs , avec plainte principale ce jour ++ . persistance d ' un aphte en jugale gauche et sur langue . douleurs gingivales predominant en bas - - > majoration COC1CCC2C3C1O[C@H]1C(=O)CC[C@@]4(O)[C@@H](C2)N(C)CC[C@]314.CL en diminuant le nombre d ' interdose pour ameliorer tolerance .
# * du point de vue infectieux : aucune documentation bacterio , viro en cours de meme que champignons . apyretique mais douleurs abdo + crp remontant 320 , anaerobies non couverts \- - > ajout CC1=NC=C(N1CCO)[N+]([O-])=O
# * du point de vue general : n ' est pas confuse ni desorientee ce jour . auscultation pulmonaire libre , en amelioration /hier , a noter leger foyer de crepitant en paravertebral droit bas .
# poids en attente ce jour .
# * du point de vue biologique :
# \- amelioration du bh avec cytolyse 1 . 5 n , cholestase <3n , bili normale .
# \- taux metho 0 . 11 ( 0 . 12 hier ) : arret bicar , poursuite levofolinate , controle taux demain pour rechercher rebond .
# \- taux CC1=CN(C=N1)C1=CC(NC(=O)C2=CC=C(C)C(NC3=NC=CC(=N3)C3=CN=CC=C3)=C2)=CC(=C1)C(F)(F)F residuel ok 0 . 96 avant arret : discuter reprise rapide .
# \- transcrit : myelo 6 . 1 % , sang 3 % : reponse partielle .
# 28/04 guillermin
# * du point de vue de la mucite : amelioration nette , sous antifongique local . ajout [Cl-].[Cl-].[Ca++] . poursuite pca COC1CCC2C3C1O[C@H]1C(=O)CC[C@@]4(O)[C@@H](C2)N(C)CC[C@]314.CL avec peu de bolus ( 4 /24h )
# * du point de vue infectieux : apyretique , sous CO\N=C(/C(=O)N[C@@H]1C(=O)N2[C@]1([H])SCC(C[N+]1(C)CCCC1)=C2C([O-])=O)C1=CSC(N)=N1 CC1=NC=C(N1CCO)[N+]([O-])=O . sib en baisse
# * du point de vue general : va de mieux en mieux . anorexie ++ , ok pour pose de sng devant perte de poids et fonte musculaire .
# * du point de vue bio : amelioration de tous les parametres metaboliques : majoration du CC1=CN(C=N1)C1=CC(NC(=O)C2=CC=C(C)C(NC3=NC=CC(=N3)C3=CN=CC=C3)=C2)=CC(=C1)C(F)(F)F ce jour a dose pleine .
# ok position sng
# 29/04 polito
# va mieux , amelioration mucite
# eruption cutanee evocatrice d ' un zona thoracique droit - mise sous valNC1=NC(=O)C2=C(N1)N(COCCO)C=N2 3000mg/joru
# sng bien toleree
# 30/04 guillermin
# globalement va mieux , gb en legere hausse a 700 .
# la semaine prochaine : scanner cerebral pour discuter pl , myelogramme des sortie d ' aplasie avec bcr abl sang et moelle .
# en l ' attente avis [doctor] , on prevoit une irradiation cerebrale et du nevraxe puis autogreffe .
# 02/05 polito astreinte
# etat clinique satisfaisant , pas de plainte
# leucocytes 1 . 2 hb 94g/l , plaquettes 82 g/l
# bon deroulement de la nutrition enterale
# 04/05 guillermin
# va bien ce matin , douleur de gorge plus en lien avec sng que mucite : baisse de la pca .
# gb 3 . 17 , pnn 0 . 19 g/l avec myelemie d ' accompagnement : myelogramme a faire lors de la sortie effective d ' aplasie .
# scanner cerebral ce jour pour envisager pl : majoration de l ' hematome sous - dural hemispherique gauche avec signe de resaignement en son sein , responsable d ' un effet de masse sur les structures medianes , deviees vers la droite de 5 mm . majoration egalement de l ' hematome sous - dural posterieur droit , sans signe de resaignement .
# avis [doctor] ( neurochirurgien ) : pas d ' indication neurochirurgicale . pl possible si 1 a 2 cc .
# 05/05 polito
# va bien - en cours de sortie d ' aplasie , leucocytes a 4g/l , pnn en cours
# persistance douleur de gorge associee a la sonde
# pas de douleur abdo , orifice picc line inflammatoire > on poursuit protocole CCCCCCCCCCCCOCCOCCOCCOCCOCCOCCOCCOCCOCCO
# 06/05 guillermin
# va nettement mieux ce jour .
# arret des atb devant sortie d ' aplasie confirmee ( pnn 0 . 85 )
# arret de la pca de CN1CC[C@]23C4C5CCC(O)C4O[C@H]2[C@@H](O)C=C[C@H]3[C@H]1C5 et relai po
# arret de l ' hydratation .
# myelogramme ce jour .
# au vu du scanner , on sursoit a la pl , a rediscuter la semaine prochaine apres nouveau scanner .
# 07/05 polito
# va bien , myelogramme fait hier , en cours
# sortie d ' aplasie ocnfirmee
# 09/05 polito astreinte
# va bien , aspect de remission cytologique au myelogramme
# cliniquement stable , persistante douleurs de gorge sur sonde ng
# leucocytes 9 . 29g/l hb 9g/l plaquettes 467
# 13/05 polito
# va bien ce jour - bonne tolerance de la nutrition enterale a 200ml/h
